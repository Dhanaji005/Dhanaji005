# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhanaji005/Dhanaji005/blob/main/Codomax_Module_1_Python_Data_Science.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, I am Dhanaji Mali")
print("Data Science Internship - Codomax Digital Solutions")
print("Module 1: Python & Data Science Fundamentals")
# Out:
# Hello, I am Dhanaji Mali
# Data Science Internship - Codomax Digital Solutions
# Module 1: Python & Data Science Fundamentals

# %% [markdown]
# Module 1 – Python & Data Science Fundamentals

# %% [markdown]
# Day 1 – Python Basics

# %%
# Variables
name = "Dhanaji"
age = 21
height = 5.8
is_student = True

print("Name:", name)
print("Age:", age)
print("Height:", height)
print("Student:", is_student)

# Data Types
print(type(name))
print(type(age))
print(type(height))
print(type(is_student))
# Out:
# Name: Dhanaji
# Age: 21
# Height: 5.8
# Student: True
# <class 'str'>
# <class 'int'>
# <class 'float'>
# <class 'bool'>

# %%
# Arithmetic Operators

a = 20
b = 5

print("Addition:", a + b)
print("Subtraction:", a - b)
print("Multiplication:", a * b)
print("Division:", a / b)
print("Modulus:", a % b)
print("Power:", a ** b)
# Out:
# Addition: 25
# Subtraction: 15
# Multiplication: 100
# Division: 4.0
# Modulus: 0
# Power: 3200000

# %%
# Creating a List

marks = [85, 90, 78, 92, 88]

print("Marks:", marks)

# Accessing List Items
print("First mark:", marks[0])
print("Second mark:", marks[1])

# Adding an item
marks.append(95)
print("After adding:", marks)

# Removing an item
marks.remove(78)
print("After removing:", marks)

# Length of the list
print("Total marks:", len(marks))
# Out:
# Marks: [85, 90, 78, 92, 88]
# First mark: 85
# Second mark: 90
# After adding: [85, 90, 78, 92, 88, 95]
# After removing: [85, 90, 92, 88, 95]
# Total marks: 5

# %%
# Creating a Dictionary

student = {
    "name": "Dhanaji",
        "age": 21,
            "course": "Data Science"
            }

            # Printing Student Details
print("Student Details:")
print(student)

            # Accessing Dictionary Values

print("Name:", student["name"])

print("Age:", student["age"])
print("Course:", student["course"])
# Out:
# Student Details:
# {'name': 'Dhanaji', 'age': 21, 'course': 'Data Science'}
# Name: Dhanaji
# Age: 21
# Course: Data Science

# %%
# For Loop

numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print(number)

    # For Loop using range()

    for i in range(1, 6):
        print("Day", i)

        # Loop through Student Names

        students = ["Dhanaji", "Kunal", "Faiyaj", "Sayli"]

        for student in students:
            print("Student:", student)
# Out:
# 1
# Day 1
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 2
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 3
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 4
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 5
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# 2
# Day 1
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 2
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 3
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 4
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 5
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# 3
# Day 1
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 2
# Student: Dhanaji
# Student: Kunal
# Student: Faiyaj
# Student: Sayli
# Day 3
# Student: Dhanaji
# ...

# %%
# While loop example

i = 1

while i <= 5:
    print(i)
    i = i + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
# For loop with list

names = ["Amit", "Sayli", "Kunal"]

for name in names:
    print(name)
# Out:
# Amit
# Sayli
# Kunal

# %%
# Break example

for i in range(1, 6):
    if i == 3:
            break
    print(i)
# Out:
# 1
# 2

# %%
# Continue example

for i in range(1, 6):
    if i == 3:
            continue
            print(i)

# %%
# Python Functions - Basic Programs


# 1. Simple Function
def greet():
    print("Hello, Welcome to Python!")

greet()


# 2. Function with Parameter
def greet_name(name):
    print("Hello", name)

greet_name("Dhanaji")


# 3. Function for Addition
def add(a, b):
    print("Addition:", a + b)

add(10, 20)


# 4. Function with Return
def multiply(a, b):
    return a * b

result = multiply(5, 4)
print("Multiplication:", result)


# 5. Check Even or Odd
def check_number(num):
    if num % 2 == 0:
        print(num, "is Even")
    else:
        print(num, "is Odd")

check_number(10)


# 6. Find Square
def square(num):
    return num * num

print("Square:", square(5))
# Out:
# Hello, Welcome to Python!
# Hello Dhanaji
# Addition: 30
# Multiplication: 20
# 10 is Even
# Square: 25

# %%
# Python File Handling - Basic Programs

# 1. Create and Write to a File
file = open("student.txt", "w")

file.write("Name: Dhanaji\n")
file.write("Course: Data Science\n")
file.write("Internship: Codomax\n")

file.close()

print("File created and data written successfully!")


# 2. Read the File
file = open("student.txt", "r")

data = file.read()

print("\nFile Content:")
print(data)

file.close()


# 3. Append Data to the File
file = open("student.txt", "a")

file.write("Module: Python Fundamentals\n")

file.close()

print("New data added successfully!")


# 4. Read Updated File
file = open("student.txt", "r")

print("\nUpdated File Content:")
print(file.read())

file.close()
# Out:
# File created and data written successfully!
#
# File Content:
# Name: Dhanaji
# Course: Data Science
# Internship: Codomax
#
# New data added successfully!
#
# Updated File Content:
# Name: Dhanaji
# Course: Data Science
# Internship: Codomax
# Module: Python Fundamentals

# %%
# Data Science - Basic Example

# Sample data
marks = [70, 80, 65, 90, 85]

# Total marks
total = sum(marks)

# Number of students
count = len(marks)

# Average marks
average = total / count

print("Marks:", marks)
print("Total Marks:", total)
print("Number of Students:", count)
print("Average Marks:", average)
# Out:
# Marks: [70, 80, 65, 90, 85]
# Total Marks: 390
# Number of Students: 5
# Average Marks: 78.0

# %%
# Real-World Data Science Example
# Student Marks Analysis

students = {
    "Dhanaji": 85,
        "Sayli": 72,
            "Kunal": 90,
                "Priya": 78,
                    "Rahul": 65
                    }

                    # Display student marks

print("Student Marks:")

for name, marks in students.items():
                        print(name, ":", marks)

                        # Calculate average marks
                        total = sum(students.values())
                        average = total / len(students)

                        print("\nAverage Marks:", average)

                        # Find highest marks
                        highest = max(students.values())

                        print("Highest Marks:", highest)

                        # Find student with highest marks
                        for name, marks in students.items():
                            if marks == highest:
                                    print("Top Student:", name)
# Out:
# Student Marks:
# Dhanaji : 85
#
# Average Marks: 78.0
# Highest Marks: 90
# Top Student: Kunal
# Sayli : 72
#
# Average Marks: 78.0
# Highest Marks: 90
# Top Student: Kunal
# Kunal : 90
#
# Average Marks: 78.0
# Highest Marks: 90
# Top Student: Kunal
# Priya : 78
#
# Average Marks: 78.0
# Highest Marks: 90
# Top Student: Kunal
# Rahul : 65
#
# Average Marks: 78.0
# Highest Marks: 90
# Top Student: Kunal

# %%
# Basic Data Analysis

sales = [1000, 1500, 1200, 1800, 2000]

# Total Sales
total_sales = sum(sales)

# Average Sales
average_sales = total_sales / len(sales)

# Highest Sales
highest_sales = max(sales)

# Lowest Sales
lowest_sales = min(sales)

print("Sales Data:", sales)
print("Total Sales:", total_sales)
print("Average Sales:", average_sales)
print("Highest Sales:", highest_sales)
print("Lowest Sales:", lowest_sales)
# Out:
# Sales Data: [1000, 1500, 1200, 1800, 2000]
# Total Sales: 7500
# Average Sales: 1500.0
# Highest Sales: 2000
# Lowest Sales: 1000
